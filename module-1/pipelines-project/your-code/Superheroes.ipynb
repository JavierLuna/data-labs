# %%
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint

# %%
def get_csv(csv_file, enconding_value):
    df = pd.read_csv(csv_file, encoding = enconding_value, na_values=["-", False])
    return df

superheroes = get_csv("superheroes.csv", "latin-1")
superheroes_powers= get_csv("superheroespowers.csv", "latin-1")

# %% [markdown]
# ----------SUPERHEROES INFO---------------

# %%
superheroes.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics        NaN       bad   441.0
# 4   -99.0      Marvel Comics        NaN       bad   -99.0

# %%
def rename_column(df, old_column, new_column):
    return df.rename(columns = {old_column: new_column}, inplace = True)

superherores = rename_column(superheroes, "name", "Name")

superheroes.head()
# Out:
#    Unnamed: 0         Name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics        NaN       bad   441.0
# 4   -99.0      Marvel Comics        NaN       bad   -99.0

# %%
def capitalize_column_values(df, column):
    df[column] = df[column].str.capitalize()

capitalize_column_values(superheroes, "Alignment")
capitalize_column_values(superheroes, "Eye color")
capitalize_column_values(superheroes, "Skin color")

superheroes.head()
# Out:
#    Unnamed: 0         Name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    Yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      Blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      Blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     Green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      Blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics        NaN      Good   441.0
# 1   191.0  Dark Horse Comics       Blue      Good    65.0
# 2   185.0          DC Comics        Red      Good    90.0
# 3   203.0      Marvel Comics        NaN       Bad   441.0
# 4   -99.0      Marvel Comics        NaN       Bad   -99.0

# %%
def pounds_to_kilograms(df, column):
      df[column] = df[column].apply(lambda value: (value/2.205) if value > 0 else None)
            
pounds_to_kilograms(superheroes, "Weight")

superheroes.head()
# Out:
#    Unnamed: 0         Name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    Yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      Blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      Blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     Green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      Blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment      Weight
# 0   203.0      Marvel Comics        NaN      Good  200.000000
# 1   191.0  Dark Horse Comics       Blue      Good   29.478458
# 2   185.0          DC Comics        Red      Good   40.816327
# 3   203.0      Marvel Comics        NaN       Bad  200.000000
# 4   -99.0      Marvel Comics        NaN       Bad         NaN

# %%
def feet_to_meters(df, column):
    df[column] = df[column].apply(lambda value: (value/3.281) if value > 0 else None)
            
feet_to_meters(superheroes, "Height")

superheroes.head()
# Out:
#    Unnamed: 0         Name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    Yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      Blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      Blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     Green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      Blue      Cosmic Entity      Black
#
#       Height          Publisher Skin color Alignment      Weight
# 0  61.871381      Marvel Comics        NaN      Good  200.000000
# 1  58.213959  Dark Horse Comics       Blue      Good   29.478458
# 2  56.385248          DC Comics        Red      Good   40.816327
# 3  61.871381      Marvel Comics        NaN       Bad  200.000000
# 4        NaN      Marvel Comics        NaN       Bad         NaN

# %%
def rename_column(df, old_column, new_column):
    return df.rename(columns = {old_column: new_column}, inplace = True)

superherores = rename_column(superheroes, "Height", "Height (m)")
superherores = rename_column(superheroes, "Weight", "Weight (kg)")

superheroes.head()
# Out:
#    Unnamed: 0         Name Gender Eye color               Race Hair color  \
# 0         NaN       A-Bomb   Male    Yellow              Human    No Hair
# 1         1.0   Abe Sapien   Male      Blue      Icthyo Sapien    No Hair
# 2         2.0     Abin Sur   Male      Blue            Ungaran    No Hair
# 3         3.0  Abomination   Male     Green  Human / Radiation    No Hair
# 4         4.0      Abraxas   Male      Blue      Cosmic Entity      Black
#
#    Height (m)          Publisher Skin color Alignment  Weight (kg)
# 0   61.871381      Marvel Comics        NaN      Good   200.000000
# 1   58.213959  Dark Horse Comics       Blue      Good    29.478458
# 2   56.385248          DC Comics        Red      Good    40.816327
# 3   61.871381      Marvel Comics        NaN       Bad   200.000000
# 4         NaN      Marvel Comics        NaN       Bad          NaN

# %%
def change_columns_order(df, list_new_columns_order):
    return df[list_new_columns_order]

superheroes = change_columns_order(superheroes, ["Name", "Race", "Gender", "Height (m)", "Weight (kg)", "Skin color", "Hair color", "Eye color", "Alignment", "Publisher"])

superheroes.head()
# Out:
#           Name               Race Gender  Height (m)  Weight (kg) Skin color  \
# 0       A-Bomb              Human   Male   61.871381   200.000000        NaN
# 1   Abe Sapien      Icthyo Sapien   Male   58.213959    29.478458       Blue
# 2     Abin Sur            Ungaran   Male   56.385248    40.816327        Red
# 3  Abomination  Human / Radiation   Male   61.871381   200.000000        NaN
# 4      Abraxas      Cosmic Entity   Male         NaN          NaN        NaN
#
#   Hair color Eye color Alignment          Publisher
# 0    No Hair    Yellow      Good      Marvel Comics
# 1    No Hair      Blue      Good  Dark Horse Comics
# 2    No Hair      Blue      Good          DC Comics
# 3    No Hair     Green       Bad      Marvel Comics
# 4      Black      Blue       Bad      Marvel Comics

# %%
def total_nulls(df):
    return df.isnull().sum()
    
total_nulls(superheroes)
# Out:
# Name             0
# Race           304
# Gender          29
# Height (m)     217
# Weight (kg)    239
# Skin color     662
# Hair color     172
# Eye color      172
# Alignment        7
# Publisher       15
# dtype: int64

# %%
def delete_unuseful_columns(df, percentage): #Detele columns with "100% - percentage" null values
    for column in df:
        if df[column].isnull().sum() > len(df.index)*percentage/100:
            del df[column]

delete_unuseful_columns(superheroes, 50)
    
superheroes.head()
# Out:
#           Name               Race Gender  Height (m)  Weight (kg) Hair color  \
# 0       A-Bomb              Human   Male   61.871381   200.000000    No Hair
# 1   Abe Sapien      Icthyo Sapien   Male   58.213959    29.478458    No Hair
# 2     Abin Sur            Ungaran   Male   56.385248    40.816327    No Hair
# 3  Abomination  Human / Radiation   Male   61.871381   200.000000    No Hair
# 4      Abraxas      Cosmic Entity   Male         NaN          NaN      Black
#
#   Eye color Alignment          Publisher
# 0    Yellow      Good      Marvel Comics
# 1      Blue      Good  Dark Horse Comics
# 2      Blue      Good          DC Comics
# 3     Green       Bad      Marvel Comics
# 4      Blue       Bad      Marvel Comics

# %%
def rename_nulls(df): #Replace NaN with "-"
    df.fillna("-", inplace=True)
    
rename_nulls(superheroes)

superheroes.head()
# Out:
#           Name               Race Gender Height (m) Weight (kg) Hair color  \
# 0       A-Bomb              Human   Male    61.8714         200    No Hair
# 1   Abe Sapien      Icthyo Sapien   Male     58.214     29.4785    No Hair
# 2     Abin Sur            Ungaran   Male    56.3852     40.8163    No Hair
# 3  Abomination  Human / Radiation   Male    61.8714         200    No Hair
# 4      Abraxas      Cosmic Entity   Male          -           -      Black
#
#   Eye color Alignment          Publisher
# 0    Yellow      Good      Marvel Comics
# 1      Blue      Good  Dark Horse Comics
# 2      Blue      Good          DC Comics
# 3     Green       Bad      Marvel Comics
# 4      Blue       Bad      Marvel Comics

# %% [markdown]
# ----------SUPERHEROES POWERS---------------

# %%
superheroes_powers.head()
# Out:
#     hero_names Agility Accelerated Healing Lantern Power Ring  \
# 0      3-D Man    True                 NaN                NaN
# 1       A-Bomb     NaN                True                NaN
# 2   Abe Sapien    True                True                NaN
# 3     Abin Sur     NaN                 NaN               True
# 4  Abomination     NaN                True                NaN
#
#   Dimensional Awareness Cold Resistance Durability Stealth Energy Absorption  \
# 0                   NaN             NaN        NaN     NaN               NaN
# 1                   NaN             NaN       True     NaN               NaN
# 2                   NaN            True       True     NaN               NaN
# 3                   NaN             NaN        NaN     NaN               NaN
# 4                   NaN             NaN        NaN     NaN               NaN
#
#   Flight  ... Web Creation Reality Warping Odin Force Symbiote Costume  \
# ...

# %%
def rename_column(df, old_column, new_column):
    return df.rename(columns = {old_column: new_column}, inplace = True)

superherores_powers = rename_column(superheroes_powers, "hero_names", "Name")

superheroes_powers.head()
# Out:
#           Name Agility Accelerated Healing Lantern Power Ring  \
# 0      3-D Man    True                 NaN                NaN
# 1       A-Bomb     NaN                True                NaN
# 2   Abe Sapien    True                True                NaN
# 3     Abin Sur     NaN                 NaN               True
# 4  Abomination     NaN                True                NaN
#
#   Dimensional Awareness Cold Resistance Durability Stealth Energy Absorption  \
# 0                   NaN             NaN        NaN     NaN               NaN
# 1                   NaN             NaN       True     NaN               NaN
# 2                   NaN            True       True     NaN               NaN
# 3                   NaN             NaN        NaN     NaN               NaN
# 4                   NaN             NaN        NaN     NaN               NaN
#
#   Flight  ... Web Creation Reality Warping Odin Force Symbiote Costume  \
# ...

# %%
def rename_trues_and_falses(df): #Replace False with "-" and True with "X"
    df.replace(to_replace = {False: None, True: "X"}, inplace = True)

rename_trues_and_falses(superheroes_powers)

superheroes_powers.head()
# Out:
#           Name Agility Accelerated Healing Lantern Power Ring  \
# 0      3-D Man       X                 NaN                NaN
# 1       A-Bomb     NaN                   X                NaN
# 2   Abe Sapien       X                   X                NaN
# 3     Abin Sur     NaN                 NaN                  X
# 4  Abomination     NaN                   X                NaN
#
#   Dimensional Awareness Cold Resistance Durability Stealth Energy Absorption  \
# 0                   NaN             NaN        NaN     NaN               NaN
# 1                   NaN             NaN          X     NaN               NaN
# 2                   NaN               X          X     NaN               NaN
# 3                   NaN             NaN        NaN     NaN               NaN
# 4                   NaN             NaN        NaN     NaN               NaN
#
#   Flight  ... Web Creation Reality Warping Odin Force Symbiote Costume  \
# ...

# %%
def total_nulls(df):
    return df.isnull().sum()
    
total_nulls(superheroes_powers)
# Out:
# Name                       0
# Agility                  425
# Accelerated Healing      489
# Lantern Power Ring       656
# Dimensional Awareness    642
# Cold Resistance          620
# Durability               410
# Stealth                  541
# Energy Absorption        590
# Flight                   455
# Danger Sense             637
# Underwater breathing     646
# Marksmanship             548
# Weapons Master           562
# Power Augmentation       659
# Animal Attributes        642
# Longevity                554
# Intelligence             509
# Super Strength           307
# Cryokinesis              648
# Telepathy                575
# Energy Armor             659
# Energy Blasts            520
# Duplication              651
# Size Changing            612
# Density Control          652
# Stamina                  378
# Astral Travel            663
# Audio Control            660
# Dexterity                661
#                         ...
# Intuitive aptitude       666
# ...

# %%
def delete_unuseful_columns(df, percentage): #Detele columns with "100% - percentage" null values
    for column in df:
        if df[column].isnull().sum() > len(df.index)*percentage/100:
            del df[column]

delete_unuseful_columns(superheroes_powers, 75)
    
superheroes_powers.head()
# Out:
#           Name Agility Accelerated Healing Durability Flight Super Strength  \
# 0      3-D Man       X                 NaN        NaN    NaN              X
# 1       A-Bomb     NaN                   X          X    NaN              X
# 2   Abe Sapien       X                   X          X    NaN              X
# 3     Abin Sur     NaN                 NaN        NaN    NaN            NaN
# 4  Abomination     NaN                   X        NaN    NaN              X
#
#   Stamina Super Speed
# 0       X           X
# 1       X         NaN
# 2       X         NaN
# 3     NaN         NaN
# 4       X           X

# %%
def rename_nulls(df): #Replace NaN with "-"
    df.fillna("-", inplace=True)
    
rename_nulls(superheroes_powers)

superheroes_powers.head()
# Out:
#           Name Agility Accelerated Healing Durability Flight Super Strength  \
# 0      3-D Man       X                   -          -      -              X
# 1       A-Bomb       -                   X          X      -              X
# 2   Abe Sapien       X                   X          X      -              X
# 3     Abin Sur       -                   -          -      -              -
# 4  Abomination       -                   X          -      -              X
#
#   Stamina Super Speed
# 0       X           X
# 1       X           -
# 2       X           -
# 3       -           -
# 4       X           X

# %% [markdown]
# ----------SUPERHEROES FULL DATA---------------

# %%
#Merge superheroes + superheroes_powers:
superheroes_full_data = pd.merge(superheroes, superheroes_powers, on='Name')
superheroes_full_data.head()
# Out:
#           Name               Race Gender Height (m) Weight (kg) Hair color  \
# 0       A-Bomb              Human   Male    61.8714         200    No Hair
# 1   Abe Sapien      Icthyo Sapien   Male     58.214     29.4785    No Hair
# 2     Abin Sur            Ungaran   Male    56.3852     40.8163    No Hair
# 3  Abomination  Human / Radiation   Male    61.8714         200    No Hair
# 4      Abraxas      Cosmic Entity   Male          -           -      Black
#
#   Eye color Alignment          Publisher Agility Accelerated Healing  \
# 0    Yellow      Good      Marvel Comics       -                   X
# 1      Blue      Good  Dark Horse Comics       X                   X
# 2      Blue      Good          DC Comics       -                   -
# 3     Green       Bad      Marvel Comics       -                   X
# 4      Blue       Bad      Marvel Comics       -                   -
#
#   Durability Flight Super Strength Stamina Super Speed
# ...

# %% [markdown]
# ----------ANALYSIS---------------

# %%
def column_values_sum(df, column, value): #Return column + values sum
    return column, (df[column] == value).sum()

# %%
Powers = []
for value in superheroes_powers.columns[1:]:
    Powers.append(column_values_sum(superheroes_full_data, value, "X"))

Powers = dict(Powers)

pprint(Powers)
# Out:
# {'Accelerated Healing': 181,
#  'Agility': 244,
#  'Durability': 262,
#  'Flight': 212,
#  'Stamina': 294,
#  'Super Speed': 251,
#  'Super Strength': 362}

# %%
plt.bar(range(len(Powers)), Powers.values(), align = "center") 
plt.xticks(range(len(Powers)), list(Powers.keys()), rotation = "vertical")
plt.title("Superheroe powers")

plt.show()

# %%
def column_values_sum2(df, column, value): #Return value + values sum
    return value, (df[column] == value).sum()

# %%
Gender = []
for value in superheroes_full_data.Gender:
    Gender.append(column_values_sum2(superheroes_full_data, "Gender", value))

Gender = dict(Gender)

pprint(Gender)
# Out:
# {'-': 18, 'Female': 178, 'Male': 464}

# %%
plt.bar(range(len(Gender)), Gender.values(), align = "center") 
plt.xticks(range(len(Gender)), list(Gender.keys()))
plt.title("Superheroe gender")

plt.show()

# %%
superheroes_full_data[superheroes_full_data.Gender == "-"] #Check the indeterminated values:
# Out:
#                  Name           Race Gender Height (m) Weight (kg)  \
# 81         Bird-Brain              -      -          -           -
# 121            Box IV              -      -          -           -
# 146  Captain Universe  God / Eternal      -          -           -
# 210               Ego              -      -          -           -
# 224     Fabian Cortez              -      -    59.7379     43.5374
# 228             Feral              -      -    53.3374     22.6757
# 232          Firelord              -      -    58.8235      44.898
# 241             Forge              -      -    55.7757     36.7347
# 253    Ghost Rider II              -      -          -           -
# 257          Godzilla          Kaiju      -    32.9168           -
# 365      Living Brain              -      -    60.3475     163.265
# 366   Living Tribunal  Cosmic Entity      -          -           -
# 378       Machine Man              -      -    55.7757     173.696
# ...

# %%
import pandas as pd

# %%
def get_csv():
    df = pd.read_csv("superheroes.csv", index_col = 0, encoding = "latin-1", na_values=["-"])
    return df

superheroes = get_csv()

# %%
def rename_column(df, old_column, new_column):
    return df.rename(columns = {old_column: new_column}, inplace = True)

superherores = rename_column(superheroes, "name", "Name")

superheroes.head()
# Out:
#           Name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics        NaN      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics        NaN       bad   441.0
# 4      Marvel Comics        NaN       bad   -99.0

# %%
def rename_column_values(df, column, old_value, new_value):
    return df[column].replace(to_replace = {old_value: new_value}, inplace=True)

rename_column_values(superheroes, "Gender", "Male", "M")
rename_column_values(superheroes, "Gender", "Female", "F")

superheroes.head()
# Out:
#           Name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb      M    yellow              Human    No Hair   203.0
# 1   Abe Sapien      M      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur      M      blue            Ungaran    No Hair   185.0
# 3  Abomination      M     green  Human / Radiation    No Hair   203.0
# 4      Abraxas      M      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics        NaN      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics        NaN       bad   441.0
# 4      Marvel Comics        NaN       bad   -99.0

# %%
def capitalize_column_values(df, column):
    df[column] = df[column].str.capitalize()

capitalize_column_values(superheroes, "Alignment")
capitalize_column_values(superheroes, "Eye color")
capitalize_column_values(superheroes, "Skin color")

superheroes.head()
# Out:
#           Name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb      M    Yellow              Human    No Hair   203.0
# 1   Abe Sapien      M      Blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur      M      Blue            Ungaran    No Hair   185.0
# 3  Abomination      M     Green  Human / Radiation    No Hair   203.0
# 4      Abraxas      M      Blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics        NaN      Good   441.0
# 1  Dark Horse Comics       Blue      Good    65.0
# 2          DC Comics        Red      Good    90.0
# 3      Marvel Comics        NaN       Bad   441.0
# 4      Marvel Comics        NaN       Bad   -99.0

# %%
def pounds_to_kilograms(df, column):
    for value in df[column]:
        if value > 0:
            df[column].replace(to_replace = {value: value/2.205}, inplace = True)
        else:
            df[column].replace(to_replace = {value: None}, inplace = True)
        
pounds_to_kilograms(superheroes, "Weight")

superheroes.head()
# Out:
#           Name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb      M    Yellow              Human    No Hair   203.0
# 1   Abe Sapien      M      Blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur      M      Blue            Ungaran    No Hair   185.0
# 3  Abomination      M     Green  Human / Radiation    No Hair   203.0
# 4      Abraxas      M      Blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment     Weight
# 0      Marvel Comics        NaN      Good  90.702948
# 1  Dark Horse Comics       Blue      Good  13.368915
# 2          DC Comics        Red      Good  18.510806
# 3      Marvel Comics        NaN       Bad  90.702948
# 4      Marvel Comics        NaN       Bad        NaN

# %%
def feet_to_meters(df, column):
    for value in df[column]:
        if value > 0:
            df[column].replace(to_replace = {value: value/3.281}, inplace = True)
        else:
            df[column].replace(to_replace = {value: None}, inplace = True)
        
feet_to_meters(superheroes, "Height")

superheroes.head()
# Out:
#           Name Gender Eye color               Race Hair color     Height  \
# 0       A-Bomb      M    Yellow              Human    No Hair   5.747478
# 1   Abe Sapien      M      Blue      Icthyo Sapien    No Hair  17.742749
# 2     Abin Sur      M      Blue            Ungaran    No Hair  17.185385
# 3  Abomination      M     Green  Human / Radiation    No Hair   5.747478
# 4      Abraxas      M      Blue      Cosmic Entity      Black        NaN
#
#            Publisher Skin color Alignment     Weight
# 0      Marvel Comics        NaN      Good  90.702948
# 1  Dark Horse Comics       Blue      Good  13.368915
# 2          DC Comics        Red      Good  18.510806
# 3      Marvel Comics        NaN       Bad  90.702948
# 4      Marvel Comics        NaN       Bad        NaN

# %%
def change_columns_order(df, list_new_columns_order):
    return df[list_new_columns_order]

superheroes = change_columns_order(superheroes, ["Name", "Race", "Gender", "Height", "Weight", "Skin color", "Hair color", "Eye color", "Alignment", "Publisher"])

superheroes.head()
# Out:
#           Name               Race Gender     Height     Weight Skin color  \
# 0       A-Bomb              Human      M   5.747478  90.702948        NaN
# 1   Abe Sapien      Icthyo Sapien      M  17.742749  13.368915       Blue
# 2     Abin Sur            Ungaran      M  17.185385  18.510806        Red
# 3  Abomination  Human / Radiation      M   5.747478  90.702948        NaN
# 4      Abraxas      Cosmic Entity      M        NaN        NaN        NaN
#
#   Hair color Eye color Alignment          Publisher
# 0    No Hair    Yellow      Good      Marvel Comics
# 1    No Hair      Blue      Good  Dark Horse Comics
# 2    No Hair      Blue      Good          DC Comics
# 3    No Hair     Green       Bad      Marvel Comics
# 4      Black      Blue       Bad      Marvel Comics

# %%
def total_nulls(df):
    return df.isnull().sum()
    
total_nulls(superheroes)
# Out:
# Name            0
# Race          304
# Gender         29
# Height        217
# Weight        239
# Skin color    662
# Hair color    172
# Eye color     172
# Alignment       7
# Publisher      15
# dtype: int64

# %%
def delete_unuseful_columns(df): #Detele columns with >50% null values
    for column in df:
        if df[column].isnull().sum() > len(df.index)*0.50:
            del df[column]

delete_unuseful_columns(superheroes)
    
superheroes.head()
# Out:
#           Name               Race Gender     Height     Weight Hair color  \
# 0       A-Bomb              Human      M   5.747478  90.702948    No Hair
# 1   Abe Sapien      Icthyo Sapien      M  17.742749  13.368915    No Hair
# 2     Abin Sur            Ungaran      M  17.185385  18.510806    No Hair
# 3  Abomination  Human / Radiation      M   5.747478  90.702948    No Hair
# 4      Abraxas      Cosmic Entity      M        NaN        NaN      Black
#
#   Eye color Alignment          Publisher
# 0    Yellow      Good      Marvel Comics
# 1      Blue      Good  Dark Horse Comics
# 2      Blue      Good          DC Comics
# 3     Green       Bad      Marvel Comics
# 4      Blue       Bad      Marvel Comics

# %%
def rename_nulls(df): #Replace "NaN" with "-"
    df.fillna("-", inplace=True)
    
rename_nulls(superheroes)

superheroes.head()
# Out:
#           Name               Race Gender   Height   Weight Hair color  \
# 0       A-Bomb              Human      M  5.74748  90.7029    No Hair
# 1   Abe Sapien      Icthyo Sapien      M  17.7427  13.3689    No Hair
# 2     Abin Sur            Ungaran      M  17.1854  18.5108    No Hair
# 3  Abomination  Human / Radiation      M  5.74748  90.7029    No Hair
# 4      Abraxas      Cosmic Entity      M        -        -      Black
#
#   Eye color Alignment          Publisher
# 0    Yellow      Good      Marvel Comics
# 1      Blue      Good  Dark Horse Comics
# 2      Blue      Good          DC Comics
# 3     Green       Bad      Marvel Comics
# 4      Blue       Bad      Marvel Comics

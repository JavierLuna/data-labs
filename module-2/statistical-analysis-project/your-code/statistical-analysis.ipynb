# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr

# %% [markdown]
# ### Now we code to read the csv doc

# %%
data = pd.read_csv(r'./train.csv')

# %% [markdown]
# ### We have to see the type of data we have, and which how many columns we are deeling with

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# ## Now we visualize how much high was the Sales Prices through the years in the data base. And we can see head to head the Sale Prices from different types of Sale.

# %% [markdown]
# ### The conclusions we can take from this quick analysis: are that the most mayority of the tickets sales are from the WD type. Followed by the New Type and the third in this case will be COD type.

# %%
data.groupby(['YrSold', 'SaleType']).sum().unstack().plot(y='SalePrice', kind='bar', stacked=True, figsize=(10, 10))

# %% [markdown]
# ## Now we can try to dig deeper into "One Variable Analysis"

# %%
data = pd.DataFrame({'YrSold':range(81), 'SalePrice':[2*i for i in range(81)]})
data.corr()
# Out:
#            YrSold  SalePrice
# YrSold        1.0        1.0
# SalePrice     1.0        1.0

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119523da0>,
# ...
#         ...,
# ...
#         ...,
# ...
#         ...,
# ...
#        ...,
# ...
#         ...,
# ...
#         ...,
# ...
#         ...,
# ...
#       dtype=object)
